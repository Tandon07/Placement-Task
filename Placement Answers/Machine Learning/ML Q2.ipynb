# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r'C:\Users\tando\Downloads\archive (5)\ObesityDataSet_raw_and_data_sinthetic.csv')

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (2087, 17)

# %%
2087+24
# Out:
# 2111

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2087 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2087 non-null   object
#  1   Age                             2087 non-null   float64
#  2   Height                          2087 non-null   float64
#  3   Weight                          2087 non-null   float64
#  4   family_history_with_overweight  2087 non-null   object
#  5   FAVC                            2087 non-null   object
#  6   FCVC                            2087 non-null   float64
#  7   NCP                             2087 non-null   float64
#  8   CAEC                            2087 non-null   object
#  9   SMOKE                           2087 non-null   object
#  10  CH2O                            2087 non-null   float64
#  11  SCC                             2087 non-null   object
# ...

# %%
categorical_columns
# Out:
# ['Gender',
#  'family_history_with_overweight',
#  'FAVC',
#  'CAEC',
#  'SMOKE',
#  'SCC',
#  'CALC',
#  'MTRANS',
#  'NObeyesdad']

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming you have your dataset loaded into a DataFrame called 'df'

# Initialize the LabelEncoder
encoder = LabelEncoder()

# Iterate over each column in the DataFrame
for column in df.columns:
    # Check if the column contains categorical data
    if df[column].dtype == 'object':
        # Apply label encoding to the categorical column
        df[column] = encoder.fit_transform(df[column])

# Print the updated DataFrame
print(df.head())
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       0  21.0    1.62    64.0                               1     0   2.0
# 1       0  21.0    1.52    56.0                               1     0   3.0
# 2       1  23.0    1.80    77.0                               1     0   2.0
# 3       1  27.0    1.80    87.0                               0     0   3.0
# 4       1  22.0    1.78    89.8                               0     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS  NObeyesdad
# 0  3.0     2      0   2.0    0  0.0  1.0     3       3           1
# 1  3.0     2      1   3.0    1  3.0  0.0     2       3           1
# 2  3.0     2      0   2.0    0  2.0  1.0     1       3           1
# 3  3.0     2      0   2.0    0  2.0  0.0     1       4           5
# 4  1.0     2      0   2.0    0  0.0  0.0     2       3           6
# C:\Users\tando\AppData\Local\Temp\ipykernel_11988\2567051778.py:14: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.000000  1.620000   64.000000                               1
# 1          0  21.000000  1.520000   56.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               0
# 4          1  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       0  20.976842  1.710730  131.408528                               1
# 2107       0  21.982942  1.748584  133.742943                               1
# 2108       0  22.524036  1.752206  133.689352                               1
# 2109       0  24.361936  1.739450  133.346641                               1
# 2110       0  23.664709  1.738836  133.472641                               1
#
# ...

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
# Standardizing

# %%
df['Age'].
# Out:
# dtype('float64')

# %%
from sklearn.preprocessing import StandardScaler

# Assuming you have your dataset loaded into a DataFrame called 'df'
scaler = StandardScaler()
# Select the columns to standardize
for column in df.columns:
    # Check if the column contains categorical data
    if df[column].dtype == 'float64':
        # Apply label encoding to the categorical column
        
        df[column] = scaler.fit_transform(df[column].values.reshape(-1,1))
# Out:
# C:\Users\tando\AppData\Local\Temp\ipykernel_11988\1907791100.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = scaler.fit_transform(df[column].values.reshape(-1,1))
# C:\Users\tando\AppData\Local\Temp\ipykernel_11988\1907791100.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = scaler.fit_transform(df[column].values.reshape(-1,1))
# C:\Users\tando\AppData\Local\Temp\ipykernel_11988\1907791100.py:11: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       Gender       Age    Height    Weight  family_history_with_overweight  \
# 0          0 -0.526613 -0.887408 -0.872985                               1
# 1          0 -0.526613 -1.960788 -1.178508                               1
# 2          1 -0.212507  1.044677 -0.376509                               1
# 3          1  0.415705  1.044677  0.005395                               0
# 4          1 -0.369560  0.830001  0.112328                               0
# ...      ...       ...       ...       ...                             ...
# 2106       0 -0.530250  0.086470  1.701376                               1
# 2107       0 -0.372239  0.492788  1.790528                               1
# 2108       0 -0.287258  0.531665  1.788482                               1
# 2109       0  0.001389  0.394745  1.775393                               1
# 2110       0 -0.108112  0.388155  1.780205                               1
#
# ...

# %%
# Now applying modelling
